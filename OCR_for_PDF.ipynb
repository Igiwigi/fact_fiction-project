# %%
#doing ocr for the royal society data etc. so its cleaner and easier to work with (in text form)
import os
import pytesseract
from pdf2image import convert_from_path
from concurrent.futures import ThreadPoolExecutor

#a little sloppily done but its ok
#pdf_dir = 'D:/Fact_fiction_corpus/texts/royal society/pdf'
pdf_dir = 'D:/Fact_fiction_corpus/texts/royal society/pdf_rsta'
#txt_dir = 'D:/Fact_fiction_corpus/texts/royal society/txt'
txt_dir = 'D:/Fact_fiction_corpus/texts/royal society/txt_rsta'


os.makedirs(txt_dir, exist_ok=True)

# Configure Tesseract to use Old English language model 'enm'
#custom_config = r'--oem 1 --psm 4 -l enm'

custom_config = r'--oem 1 --psm 4 -l eng'

def process_pdf(pdf_file):
    if pdf_file.endswith('.pdf'):
        pdf_path = os.path.join(pdf_dir, pdf_file)
        txt_file = os.path.splitext(pdf_file)[0] + '.txt'
        txt_path = os.path.join(txt_dir, txt_file)

        # Check if the text file already exists
        if os.path.exists(txt_path):
            print(f"{txt_file} already exists, skipping OCR...")
            return

        images = convert_from_path(pdf_path)
        
        print(f"Processing {pdf_file}...")

        full_text = []

        for i, image in enumerate(images):
            image = image.convert('L')  # Convert image to grayscale
            text = pytesseract.image_to_string(image, config=custom_config)
            full_text.append(text)

        with open(txt_path, 'w', encoding='utf-8') as f:
            f.write('\n\n'.join(full_text))
        
        print(f"Combined text saved as {txt_file}")

pdf_files = [f for f in os.listdir(pdf_dir) if f.endswith('.pdf')]

#concurrent processing with thread pool
with ThreadPoolExecutor(max_workers=os.cpu_count()) as executor:
    executor.map(process_pdf, pdf_files)

print("Conversion complete.")
# Out:
# Processing rsta20230326.pdf...
# Processing rsta_2022_0155.pdf...
# Processing rsta_2015_0174.pdf...
# Processing rsta_2022_0143.pdf...
# Processing rsta20230313.pdf...
# Processing rsta_2015_0190.pdf...Processing rsta_2022_0149.pdf...
#
# Processing rsta20230324.pdf...
# Processing rsta_2015_0181.pdf...
# Combined text saved as rsta20230326.txt
# Processing rsta_2015_0341.pdf...
# Processing rsta_2022_0156.pdf...
# Processing rsta_2015_0166.pdf...
# Processing rsta_2015_0202.pdf...
# Combined text saved as rsta_2022_0155.txt
# Processing rsta_2015_0189.pdf...
# Combined text saved as rsta20230324.txt
# Processing rsta_2015_0205.pdf...
# Combined text saved as rsta_2022_0143.txt
# Combined text saved as rsta_2015_0174.txt
# Combined text saved as rsta_2015_0190.txt
# Processing rsta_2015_0183.pdf...
# Processing rsta_2015_0204.pdf...
# Processing rsta_2015_0185.pdf...
# Combined text saved as rsta_2015_0202.txt
# Processing rsta_2015_0237.pdf...
# Combined text saved as rsta20230313.txt
# Processing rsta_2013_0406.pdf...
# Combined text saved as rsta_2015_0189.txt
# Processing rsta_2015_0284.pdf...
# Combined text saved as rsta_2022_0149.txt
# Processing rsta_2015_0269.pdf...
# Combined text saved as rsta_2015_0284.txt
# Processing rsta_2016_0075.pdf...
# Combined text saved as rsta_2015_0181.txt
# Processing rsta_2016_0018.pdf...
# Combined text saved as rsta_2015_0205.txt
# Combined text saved as rsta_2015_0166.txt
# Processing rsta_2015_0270.pdf...
# Combined text saved as rsta_2016_0075.txt
# Combined text saved as rsta_2015_0237.txt
# Processing rsta_2015_0277.pdf...
# Processing rsta_2015_0137.pdf...
# Processing rsta_2015_0125.pdf...
# Combined text saved as rsta_2013_0406.txt
# Processing rsta_2015_0134.pdf...
# Combined text saved as rsta_2015_0204.txt
# Processing rsta_2015_0139.pdf...
# Combined text saved as rsta_2022_0156.txt
# Processing rsta_2013_0401.pdf...
# Combined text saved as rsta_2015_0183.txt
# Processing rsta_2015_0310.pdf...
# Combined text saved as rsta_2015_0341.txt
# Processing rsta_2013_0398.pdf...
# Combined text saved as rsta_2015_0269.txt
# Processing rsta_2013_0400.pdf...
# Combined text saved as rsta_2016_0018.txt
# Combined text saved as rsta_2015_0137.txt
# Processing rsta_2013_0403.pdf...
# Combined text saved as rsta_2015_0277.txt
# Processing rsta_2013_0402.pdf...
# Combined text saved as rsta_2015_0270.txt
# Processing rsta_2013_0405.pdf...
# Combined text saved as rsta_2015_0185.txt
# Processing rsta_2014_0020.pdf...
# Processing rsta_2013_0397.pdf...
# Combined text saved as rsta_2015_0139.txt
# Processing rsta_2014_0207.pdf...
# Combined text saved as rsta_2013_0398.txt
# Combined text saved as rsta_2014_0207.txt
# Processing rsta_2014_0068.pdf...
# Processing rsta_2014_0195.pdf...
# Combined text saved as rsta_2015_0125.txt
# Processing rsta_2014_0206.pdf...
# Combined text saved as rsta_2015_0134.txt
# Processing rsta_2014_0051.pdf...
# Combined text saved as rsta_2015_0310.txt
# Processing rsta_2014_0065.pdf...
# Combined text saved as rsta_2013_0402.txt
# Combined text saved as rsta_2013_0401.txt
# Processing rsta_2014_0033.pdf...
# Combined text saved as rsta_2014_0020.txt
# Processing rsta_2014_0046.pdf...
# Processing rsta_2014_0108.pdf...
# Combined text saved as rsta_2013_0403.txt
# Combined text saved as rsta_2014_0206.txt
# Combined text saved as rsta_2014_0068.txt
# Processing rsta_2014_0111.pdf...
# Processing rsta_2014_0114.pdf...
# Combined text saved as rsta_2014_0195.txt
# Combined text saved as rsta_2013_0405.txt
# Processing rsta20080136.pdf...
# Combined text saved as rsta_2013_0400.txt
# Processing rsta_2014_0092.pdf...
# Processing rsta_2014_0117.pdf...
# Processing rsta_2014_0345.pdf...
# Combined text saved as rsta_2014_0051.txt
# Processing rsta20080132.pdf...
# Combined text saved as rsta_2013_0397.txt
# Combined text saved as rsta_2014_0046.txt
# Processing rsta20080139.pdf...
# Processing rsta20080146.pdf...
# Combined text saved as rsta_2014_0033.txt
# Processing rsta20080215.pdf...
# Combined text saved as rsta20080146.txt
# Processing rsta_2008_3000.pdf...
# Combined text saved as rsta_2008_3000.txt
# Processing rsta20072068.pdf...
# Combined text saved as rsta20080215.txt
# Processing rsta_2022_0209.pdf...
# Combined text saved as rsta_2014_0065.txt
# Processing rsta_2021_0197.pdf...
# Combined text saved as rsta_2014_0345.txt
# Combined text saved as rsta20080136.txt
# Combined text saved as rsta_2014_0114.txt
# Processing rsta_2021_0421.pdf...
# Combined text saved as rsta_2014_0108.txt
# Processing rsta_2021_0074.pdf...
# Processing rsta_2021_0106.pdf...
# Combined text saved as rsta_2021_0421.txt
# Processing rsta_2021_0089.pdf...
# Combined text saved as rsta_2022_0209.txt
# Combined text saved as rsta_2014_0117.txt
# Processing rsta_2020_0440.pdf...
# Processing rsta_2020_0450.pdf...
# Combined text saved as rsta_2014_0092.txt
# Processing rsta_2020_0457.pdf...
# Processing rsta_2010_0240.pdf...
# Combined text saved as rsta20080132.txt
# Processing rsta_2020_0340.pdf...
# Combined text saved as rsta20072068.txt
# Combined text saved as rsta_2014_0111.txt
# Combined text saved as rsta_2021_0197.txt
# Processing rsta_2020_0349.pdf...
# Processing rsta_2020_0274.pdf...
# Processing rsta_2020_0399.pdf...
# Combined text saved as rsta_2021_0074.txt
# Processing rsta_2020_0280.pdf...
# Combined text saved as rsta_2020_0340.txt
# Combined text saved as rsta_2021_0089.txt
# Processing rsta_2020_0269.pdf...
# Processing rsta_2021_0001.pdf...
# Combined text saved as rsta_2020_0440.txt
# Processing rsta_2020_0278.pdf...
# Combined text saved as rsta_2020_0280.txtCombined text saved as rsta20080139.txt
#
# Processing rsta20072001.pdf...
# Processing rsta_2020_0276.pdf...
# Combined text saved as rsta_2021_0106.txt
# Processing rsta20061957.pdf...
# Combined text saved as rsta20061957.txt
# Combined text saved as rsta_2020_0274.txt
# Processing rsta_2007_3001.pdf...
# Processing rsta20061952.pdf...
# Combined text saved as rsta_2007_3001.txt
# Processing rsta20061926.pdf...
# Combined text saved as rsta_2020_0399.txt
# Processing rsta_2007_3002.pdf...
# Combined text saved as rsta_2007_3002.txt
# Processing rsta20072161.pdf...
# Combined text saved as rsta20072161.txt
# Processing rsta_2006_2003.pdf...
# Combined text saved as rsta_2006_2003.txt
# Combined text saved as rsta_2020_0450.txt
# Processing rsta_2006_2002.pdf...
# Combined text saved as rsta20072001.txt
# Processing rsta_2006_2001.pdf...
# Processing rsta20072160.pdf...
# Combined text saved as rsta_2006_2002.txt
# Processing rsta20072121.pdf...
# Combined text saved as rsta_2020_0349.txt
# Processing rsta20072053.pdf...
# Combined text saved as rsta_2006_2001.txt
# Combined text saved as rsta20061926.txt
# Processing rsta20072119.pdf...
# Processing rsta20072120.pdf...
# Combined text saved as rsta20072053.txt
# Processing rsta20072129.pdf...
# Combined text saved as rsta_2010_0240.txt
# Processing rsta20072162.pdf...
# Combined text saved as rsta_2020_0457.txt
# Processing rsta20072196.pdf...
# Combined text saved as rsta20072162.txt
# Processing rsta20080029.pdf...
# Combined text saved as rsta20072120.txt
# Combined text saved as rsta20072119.txt
# Processing rsta20080021.pdf...
# Processing rsta20080011.pdf...
# Combined text saved as rsta20072121.txt
# Processing rsta20080046.pdf...
# Combined text saved as rsta20072129.txt
# Combined text saved as rsta20080029.txt
# Processing rsta20080044.pdf...
# Processing rsta20080040.pdf...
# Combined text saved as rsta20072160.txt
# Processing rsta20080028.pdf...
# Combined text saved as rsta20080046.txt
# Combined text saved as rsta_2020_0269.txt
# Processing rsta20080056.pdf...
# Processing rsta20080045.pdf...
# Combined text saved as rsta_2020_0278.txt
# Processing rsta20080098.pdf...
# Combined text saved as rsta20061952.txt
# Combined text saved as rsta20072196.txt
# Processing rsta20080075.pdf...
# Processing rsta20080130.pdf...
# Combined text saved as rsta20080028.txt
# Processing rsta20080154.pdf...
# Combined text saved as rsta_2020_0276.txt
# Processing rsta20080141.pdf...
# Combined text saved as rsta20080040.txt
# Processing rsta20080121.pdf...
# Combined text saved as rsta20080121.txt
# Processing rsta20080140.pdf...
# Combined text saved as rsta20080154.txt
# Processing rsta20080221.pdf...
# Combined text saved as rsta20080044.txt
# Processing rsta20080202.pdf...
# Combined text saved as rsta20080140.txt
# Processing rsta20080151.pdf...
# Combined text saved as rsta20080221.txt
# Processing rsta20080239.pdf...
# Combined text saved as rsta20080130.txt
# Processing rsta20080217.pdf...
# Combined text saved as rsta20080151.txt
# Processing rsta20080249.pdf...
# Combined text saved as rsta20080021.txt
# Combined text saved as rsta20080098.txt
# Processing rsta20080254.pdf...
# Combined text saved as rsta20080011.txt
# Processing rsta20080219.pdf...
# Combined text saved as rsta20080254.txt
# Processing rsta20080240.pdf...
# Combined text saved as rsta20080202.txt
# Processing rsta20080183.pdf...
# Combined text saved as rsta20080239.txt
# Processing rsta20080207.pdf...
# Combined text saved as rsta20080141.txt
# Processing rsta20080211.pdf...
# Combined text saved as rsta_2021_0001.txt
# Processing rsta20080210.pdf...
# Processing rsta20080190.pdf...
# Combined text saved as rsta20080217.txt
# Processing rsta20080180.pdf...
# Combined text saved as rsta20080045.txt
# Processing rsta20080193.pdf...
# Combined text saved as rsta20080249.txt
# Processing rsta20080159.pdf...
# Combined text saved as rsta20080075.txt
# Processing rsta20080175.pdf...
# Combined text saved as rsta20080183.txt
# Processing rsta20080256.pdf...
# Combined text saved as rsta20080056.txt
# Processing rsta20080292.pdf...
# Combined text saved as rsta20080180.txt
# Processing rsta20090026.pdf...
# Combined text saved as rsta20080159.txt
# Combined text saved as rsta20080193.txt
# Combined text saved as rsta20080219.txt
# Combined text saved as rsta20090026.txt
# Processing rsta20090071.pdf...
# Combined text saved as rsta20080175.txt
# Processing rsta20080310.pdf...
# Processing rsta20090011.pdf...
# Processing rsta20080308.pdf...
# Processing rsta20090034.pdf...
# Combined text saved as rsta20080292.txt
# Processing rsta20090043.pdf...
# Combined text saved as rsta20090071.txt
# Processing rsta_2009_0138.pdf...
# Combined text saved as rsta_2009_0138.txt
# Processing rsta_2009_0122.pdf...
# Combined text saved as rsta20080210.txt
# Processing rsta20090098.pdf...
# Combined text saved as rsta20080240.txt
# Processing rsta_2009_0172.pdf...
# Combined text saved as rsta_2009_0172.txt
# Combined text saved as rsta20080190.txt
# Combined text saved as rsta_2009_0122.txt
# Processing rsta_2009_0197.pdf...
# Combined text saved as rsta20080207.txt
# Combined text saved as rsta20080256.txt
# Processing rsta_2009_0165.pdf...
# Processing rsta_2009_0201.pdf...
# Processing rsta_2009_0159.pdf...
# Processing rsta_2009_0217.pdf...
# Combined text saved as rsta20090098.txt
# Processing rsta_2009_0213.pdf...
# Combined text saved as rsta_2009_0213.txt
# Processing rsta_2009_0243.pdf...
# Combined text saved as rsta20080211.txt
# Processing rsta_2009_0187.pdf...
# Combined text saved as rsta_2009_0201.txt
# Processing rsta_2009_0249.pdf...
# Combined text saved as rsta_2009_0243.txt
# Combined text saved as rsta20090034.txt
# Processing rsta_2009_0253.pdf...
# Combined text saved as rsta20080308.txt
# Processing rsta_2009_0215.pdf...
# Combined text saved as rsta_2009_0217.txt
# Combined text saved as rsta_2009_0249.txt
# Processing rsta_2009_0208.pdf...
# Processing rsta_2009_0265.pdf...
# Processing rsta_2009_0247.pdf...
# Combined text saved as rsta20090043.txt
# Processing rsta_2009_0266.pdf...
# Combined text saved as rsta_2009_0197.txt
# Combined text saved as rsta_2009_0187.txt
# Processing rsta_2009_0226.pdf...
# Processing rsta_2009_0245.pdf...
# Combined text saved as rsta20080310.txt
# Processing rsta_2009_0261.pdf...
# Combined text saved as rsta_2009_0159.txt
# Processing rsta_2009_0216.pdf...
# Combined text saved as rsta_2009_0165.txt
# Processing rsta_2010_0062.pdf...
# Combined text saved as rsta_2009_0265.txt
# Combined text saved as rsta_2009_0266.txt
# Combined text saved as rsta_2009_0215.txt
# Processing rsta_2010_0011.pdf...
# Processing rsta_2010_0052.pdf...
# Combined text saved as rsta_2009_0208.txt
# Combined text saved as rsta_2010_0062.txt
# Processing rsta_2010_0071.pdf...
# Processing rsta_2010_0083.pdf...
# Processing rsta_2010_0050.pdf...
# Combined text saved as rsta_2009_0253.txt
# Processing rsta_2010_0131.pdf...
# Combined text saved as rsta_2009_0245.txt
# Processing rsta_2010_0117.pdf...
# Combined text saved as rsta20090011.txt
# Combined text saved as rsta_2010_0131.txt
# Processing rsta_2010_0177.pdf...
# Processing rsta_2010_0026.pdf...
# Combined text saved as rsta_2009_0261.txt
# Combined text saved as rsta_2010_0177.txt
# Processing rsta_2010_0152.pdf...
# Combined text saved as rsta_2009_0226.txt
# Processing rsta_2010_0175.pdf...
# Processing rsta_2010_0205.pdf...
# Combined text saved as rsta_2009_0216.txt
# Processing rsta_2012_0141.pdf...
# Combined text saved as rsta_2012_0141.txt
# Processing rsta_2010_0294.pdf...
# Combined text saved as rsta_2010_0294.txt
# Processing rsta_2010_0139.pdf...
# Combined text saved as rsta_2010_0052.txt
# Processing rsta_2012_0221.pdf...
# Combined text saved as rsta_2010_0117.txt
# Processing rsta_2012_0106.pdf...
# Combined text saved as rsta_2010_0071.txt
# Combined text saved as rsta_2010_0026.txt
# Processing rsta_2011_0438.pdf...
# Processing rsta_2011_0269.pdf...
# Combined text saved as rsta_2011_0438.txt
# Processing rsta_2011_0468.pdf...
# Combined text saved as rsta_2010_0175.txt
# Combined text saved as rsta_2012_0221.txt
# Processing rsta_2011_0467.pdf...
# Processing rsta_2011_0316.pdf...
# Combined text saved as rsta_2010_0152.txt
# Processing rsta_2011_0304.pdf...
# Combined text saved as rsta_2010_0083.txt
# Combined text saved as rsta_2011_0467.txt
# Processing rsta_2013_0098.pdf...
# Processing rsta_2011_0371.pdf...
# Combined text saved as rsta_2011_0468.txt
# Processing rsta_2012_0516.pdf...
# Combined text saved as rsta_2013_0098.txt
# Combined text saved as rsta_2010_0139.txt
# Combined text saved as rsta_2010_0011.txt
# Processing rsta_2012_0518.pdf...
# Processing rsta_2011_0280.pdf...
# Processing rsta_2013_0121.pdf...
# Combined text saved as rsta_2012_0516.txt
# Processing rsta_2012_0523.pdf...
# Combined text saved as rsta_2011_0269.txt
# Processing rsta_2013_0039.pdf...
# Combined text saved as rsta_2011_0280.txt
# Processing rsta_2011_0177.pdf...
# Combined text saved as rsta_2012_0523.txt
# Combined text saved as rsta_2013_0039.txt
# Combined text saved as rsta_2012_0106.txt
# Processing rsta_2012_0501.pdf...
# Processing rsta_2011_0123.pdf...
# Processing rsta_2011_0302.pdf...
# Combined text saved as rsta_2010_0205.txt
# Combined text saved as rsta_2009_0247.txt
# Combined text saved as rsta_2012_0501.txt
# Processing rsta_2012_0493.pdf...
# Processing rsta_2011_0546.pdf...
# Processing rsta_2011_0548.pdf...
# Combined text saved as rsta_2012_0518.txt
# Combined text saved as rsta_2011_0177.txt
# Processing rsta_2012_0071.pdf...
# Combined text saved as rsta_2011_0371.txt
# Processing rsta_2012_0072.pdf...
# Processing rsta_2012_0095.pdf...
# Combined text saved as rsta_2010_0050.txt
# Processing rsta_2012_0435.pdf...
# Combined text saved as rsta_2013_0121.txt
# Processing rsta_2012_0457.pdf...
# Combined text saved as rsta_2012_0457.txt
# Combined text saved as rsta_2011_0304.txt
# Processing rsta_2011_0403.pdf...
# Processing rsta_2011_0596.pdf...
# Combined text saved as rsta_2011_0123.txt
# Processing rsta_2012_0296.pdf...
# Combined text saved as rsta_2012_0435.txt
# Processing rsta_2012_0332.pdf...
# Combined text saved as rsta_2011_0403.txt
# Processing rsta_2012_0333.pdf...
# Combined text saved as rsta_2012_0333.txt
# Processing rsta_2012_0338.pdf...
# Combined text saved as rsta_2012_0296.txt
# Processing rsta_2012_0020.pdf...
# Combined text saved as rsta_2012_0095.txt
# Combined text saved as rsta_2011_0316.txt
# Combined text saved as rsta_2012_0338.txt
# Processing rsta_2011_0147.pdf...
# Processing rsta_2011_0156.pdf...
# Combined text saved as rsta_2012_0332.txt
# Processing rsta_2011_0241.pdf...
# Processing rsta_2011_0239.pdf...
# Combined text saved as rsta_2012_0071.txt
# Combined text saved as rsta_2011_0241.txt
# Processing rsta_2011_0126.pdf...
# Combined text saved as rsta_2011_0147.txt
# Combined text saved as rsta_2012_0493.txt
# Processing rsta_2011_0191.pdf...
# Processing rsta_2011_0199.pdf...
# Processing rsta_2011_0080.pdf...
# Combined text saved as rsta_2011_0546.txt
# Combined text saved as rsta_2011_0191.txt
# Processing rsta_2011_0185.pdf...
# Processing rsta_2011_0117.pdf...
# Combined text saved as rsta_2011_0302.txt
# Combined text saved as rsta_2012_0072.txt
# Processing rsta_2011_0116.pdf...
# Processing rsta_2012_0243.pdf...
# Combined text saved as rsta_2011_0548.txt
# Processing rsta_2011_0526.pdf...
# Combined text saved as rsta_2011_0185.txt
# Processing rsta_2012_0370.pdf...
# Combined text saved as rsta_2011_0156.txt
# Processing rsta_2012_0331.pdf...
# Combined text saved as rsta_2012_0020.txt
# Processing rsta_2012_0404.pdf...
# Combined text saved as rsta_2012_0331.txt
# Processing rsta_2012_0403.pdf...
# Combined text saved as rsta_2011_0117.txt
# Combined text saved as rsta_2012_0403.txt
# Processing rsta_2012_0436.pdf...
# Processing rsta_2012_0085.pdf...
# Combined text saved as rsta_2012_0243.txt
# Combined text saved as rsta_2012_0404.txt
# Combined text saved as rsta_2011_0116.txt
# Processing rsta_2012_0082.pdf...
# Combined text saved as rsta_2011_0199.txt
# Processing rsta_2011_0534.pdf...
# Processing rsta_2012_0094.pdf...
# Processing rsta_2011_0553.pdf...
# Combined text saved as rsta_2012_0082.txt
# Combined text saved as rsta_2011_0080.txt
# Processing rsta_2012_0222.pdf...
# Combined text saved as rsta_2011_0596.txt
# Processing rsta_2011_0382.pdf...
# Processing rsta_2012_0496.pdf...
# Combined text saved as rsta_2011_0239.txt
# Processing rsta_2011_0406.pdf...
# Combined text saved as rsta_2012_0436.txt
# Processing rsta_2011_0166.pdf...
# Combined text saved as rsta_2011_0126.txt
# Combined text saved as rsta_2011_0406.txt
# Processing rsta_2011_0278.pdf...
# Combined text saved as rsta_2012_0370.txt
# Processing rsta_2011_0261.pdf...
# Processing rsta_2011_0313.pdf...
# Combined text saved as rsta_2011_0526.txt
# Processing rsta_2012_0512.pdf...
# Combined text saved as rsta_2011_0382.txt
# Processing rsta_2011_0366.pdf...
# Combined text saved as rsta_2011_0278.txt
# Processing rsta_2011_0303.pdf...
# Combined text saved as rsta_2012_0085.txt
# Processing rsta_2011_0065.pdf...
# Combined text saved as rsta_2011_0303.txt
# Processing rsta_2011_0299.pdf...
# Combined text saved as rsta_2012_0512.txt
# Combined text saved as rsta_2012_0094.txt
# Combined text saved as rsta_2011_0366.txt
# Combined text saved as rsta_2011_0313.txt
# Processing rsta_2011_0160.pdf...
# Processing rsta_2011_0161.pdf...
# Processing rsta_2012_0153.pdf...
# Processing rsta_2012_0510.pdf...
# Combined text saved as rsta_2011_0261.txt
# Processing rsta_2012_0294.pdf...
# Combined text saved as rsta_2012_0222.txt
# Processing rsta_2010_0351.pdf...
# Combined text saved as rsta_2010_0351.txt
# Processing rsta_2010_0303.pdf...
# Combined text saved as rsta_2011_0534.txt
# Processing rsta_2010_0375.pdf...
# Combined text saved as rsta_2012_0496.txt
# Combined text saved as rsta_2012_0510.txt
# Processing rsta_2010_0322.pdf...
# Combined text saved as rsta_2011_0553.txt
# Processing rsta_2010_0290.pdf...
# Processing rsta_2010_0304.pdf...
# Combined text saved as rsta_2010_0375.txt
# Combined text saved as rsta_2010_0304.txt
# Processing rsta_2010_0271.pdf...
# Processing rsta_2010_0246.pdf...
# Combined text saved as rsta_2012_0153.txt
# Processing rsta_2010_0277.pdf...
# Combined text saved as rsta_2011_0166.txt
# Processing rsta_2010_0293.pdf...
# Combined text saved as rsta_2011_0065.txt
# Processing rsta_2010_0289.pdf...
# Combined text saved as rsta_2010_0289.txt
# Combined text saved as rsta_2011_0161.txt
# Combined text saved as rsta_2011_0299.txt
# Processing rsta_2010_0283.pdf...
# Combined text saved as rsta_2010_0322.txt
# Processing rsta_2010_0292.pdf...
# Processing rsta_2012_0290.pdf...
# Processing rsta_2012_0086.pdf...
# Combined text saved as rsta_2010_0303.txt
# Processing rsta_2012_0064.pdf...
# Combined text saved as rsta_2012_0290.txt
# Processing rsta_2012_0167.pdf...
# Combined text saved as rsta_2011_0160.txt
# Processing rsta_2010_0372.pdf...
# Combined text saved as rsta_2010_0283.txt
# Processing rsta_2010_0339.pdf...
# Combined text saved as rsta_2010_0372.txt
# Processing rsta_2010_0338.pdf...
# Combined text saved as rsta_2010_0246.txt
# Processing rsta_2010_0332.pdf...
# Combined text saved as rsta_2010_0293.txt
# Processing rsta_2012_0340.pdf...
# Combined text saved as rsta_2010_0277.txt
# Processing rsta_2013_0301.pdf...
# Combined text saved as rsta_2010_0338.txt
# Combined text saved as rsta_2013_0301.txt
# Combined text saved as rsta_2010_0292.txt
# Processing rsta_2012_0326.pdf...
# Processing rsta_2013_0128.pdf...
# Combined text saved as rsta_2012_0064.txt
# Combined text saved as rsta_2010_0332.txt
# Processing rsta_2013_0144.pdf...
# Processing rsta_2012_0488.pdf...
# Combined text saved as rsta_2012_0294.txt
# Combined text saved as rsta_2010_0290.txt
# Combined text saved as rsta_2010_0339.txt
# Processing rsta_2013_0270.pdf...
# Combined text saved as rsta_2010_0271.txt
# Processing rsta_2013_0077.pdf...
# Processing rsta_2013_0312.pdf...
# Processing rsta_2013_0302.pdf...
# Processing rsta_2013_0100.pdf...
# Combined text saved as rsta_2012_0488.txt
# Combined text saved as rsta_2012_0340.txt
# Processing rsta_2013_0290.pdf...
# Combined text saved as rsta_2013_0128.txt
# Processing rsta_2013_0283.pdf...
# Processing rsta_2013_0381.pdf...
# Combined text saved as rsta_2013_0144.txt
# Processing rsta_2013_0387.pdf...
# Combined text saved as rsta_2012_0167.txt
# Processing rsta_2013_0407.pdf...
# Combined text saved as rsta_2013_0312.txt
# Processing rsta_2013_0341.pdf...
# Combined text saved as rsta_2013_0341.txt
# Combined text saved as rsta_2013_0077.txt
# Processing rsta_2013_0240.pdf...
# Processing rsta_2014_0027.pdf...
# Combined text saved as rsta_2012_0326.txt
# Processing rsta_2014_0253.pdf...
# Combined text saved as rsta_2013_0302.txt
# Combined text saved as rsta_2013_0283.txt
# Combined text saved as rsta_2014_0253.txt
# Processing rsta_2014_0286.pdf...
# Processing rsta_2014_0023.pdf...
# Processing rsta_2013_0340.pdf...
# Combined text saved as rsta_2013_0387.txt
# Processing rsta_2014_0029.pdf...
# Combined text saved as rsta_2013_0290.txt
# Combined text saved as rsta_2013_0381.txt
# Combined text saved as rsta_2014_0286.txt
# Combined text saved as rsta_2013_0270.txt
# Processing rsta_2014_0019.pdf...
# Processing rsta_2014_0009.pdf...
# Processing rsta_2013_0396.pdf...
# Processing rsta_2013_0360.pdf...
# Combined text saved as rsta_2013_0100.txt
# Combined text saved as rsta_2012_0086.txt
# Combined text saved as rsta_2013_0240.txt
# Processing rsta_2013_0369.pdf...
# Processing rsta_2014_0142.pdf...
# Combined text saved as rsta_2013_0407.txt
# Processing rsta_2014_0049.pdf...
# Processing rsta_2014_0198.pdf...
# Combined text saved as rsta_2014_0027.txt
# Processing rsta_2014_0103.pdf...
# Combined text saved as rsta_2014_0049.txt
# Processing rsta_2014_0112.pdf...
# Combined text saved as rsta_2014_0029.txt
# Processing rsta_2014_0113.pdf...
# Combined text saved as rsta_2014_0019.txt
# Combined text saved as rsta_2014_0009.txt
# Processing rsta_2014_0110.pdf...
# Processing rsta_2014_0094.pdf...
# Combined text saved as rsta_2014_0023.txt
# Combined text saved as rsta_2013_0396.txt
# Processing rsta_2014_0096.pdf...
# Processing rsta_2014_0098.pdf...
# Combined text saved as rsta_2013_0360.txt
# Processing rsta_2014_0088.pdf...
# Combined text saved as rsta_2014_0142.txt
# Processing rsta_2014_0080.pdf...
# Combined text saved as rsta_2014_0103.txt
# Processing rsta_2014_0075.pdf...
# Combined text saved as rsta_2013_0369.txt
# Combined text saved as rsta_2014_0112.txt
# Combined text saved as rsta_2014_0113.txt
# Processing rsta_2013_0160.pdf...
# Processing rsta_2014_0475.pdf...
# Processing rsta_2014_0070.pdf...
# Combined text saved as rsta_2014_0475.txt
# Combined text saved as rsta_2013_0160.txt
# Combined text saved as rsta_2014_0198.txt
# Processing rsta_2014_0187.pdf...
# Processing rsta_2014_0366.pdf...
# Processing rsta_2014_0177.pdf...
# Combined text saved as rsta_2014_0110.txt
# Combined text saved as rsta_2014_0088.txt
# Processing rsta_2014_0229.pdf...
# Processing rsta_2014_0130.pdf...
# Combined text saved as rsta_2014_0094.txt
# Combined text saved as rsta_2014_0098.txt
# Processing rsta_2014_0231.pdf...
# Processing rsta_2014_0234.pdf...
# Combined text saved as rsta_2013_0340.txt
# Processing rsta_2014_0227.pdf...
# Combined text saved as rsta_2014_0080.txt
# Processing rsta_2014_0230.pdf...
# Combined text saved as rsta_2014_0096.txt
# Processing rsta_2014_0155.pdf...
# Combined text saved as rsta_2014_0075.txt
# Processing rsta_2014_0147.pdf...
# Combined text saved as rsta_2014_0227.txt
# Combined text saved as rsta_2014_0070.txt
# Combined text saved as rsta_2014_0229.txt
# Processing rsta_2014_0256.pdf...
# Processing rsta_2014_0262.pdf...
# Processing rsta_2014_0268.pdf...
# Combined text saved as rsta_2014_0234.txt
# Processing rsta_2014_0261.pdf...
# Combined text saved as rsta_2014_0231.txt
# Processing rsta_2014_0398.pdf...
# Combined text saved as rsta_2014_0366.txt
# Combined text saved as rsta_2014_0230.txt
# Processing rsta_2014_0394.pdf...
# Combined text saved as rsta_2014_0155.txt
# Processing rsta_2014_0393.pdf...
# Processing rsta_2014_0389.pdf...
# Combined text saved as rsta_2014_0187.txt
# Combined text saved as rsta_2014_0130.txt
# Processing rsta_2014_0159.pdf...
# Processing rsta_2014_0170.pdf...
# Combined text saved as rsta_2014_0262.txt
# Processing rsta_2014_0225.pdf...
# Combined text saved as rsta_2014_0256.txt
# Processing rsta_2014_0220.pdf...
# Combined text saved as rsta_2014_0398.txt
# Processing rsta_2014_0224.pdf...
# Combined text saved as rsta_2014_0389.txt
# Combined text saved as rsta_2014_0147.txt
# Processing rsta_2014_0341.pdf...
# Combined text saved as rsta_2014_0394.txt
# Processing rsta_2014_0338.pdf...
# Combined text saved as rsta_2014_0268.txt
# Processing rsta_2015_0074.pdf...
# Processing rsta_2014_0343.pdf...
# Combined text saved as rsta_2014_0170.txt
# Processing rsta_2014_0330.pdf...
# Combined text saved as rsta_2014_0393.txt
# Combined text saved as rsta_2014_0159.txt
# Combined text saved as rsta_2014_0177.txt
# Processing rsta_2014_0335.pdf...
# Processing rsta_2014_0339.pdf...
# Combined text saved as rsta_2014_0261.txt
# Combined text saved as rsta_2014_0225.txt
# Processing rsta_2014_0334.pdf...
# Processing rsta_2014_0363.pdf...
# Processing rsta_2014_0360.pdf...
# Combined text saved as rsta_2015_0074.txt
# Processing rsta_2014_0283.pdf...
# Combined text saved as rsta_2014_0343.txt
# Processing rsta_2014_0449.pdf...
# Combined text saved as rsta_2014_0224.txt
# Combined text saved as rsta_2014_0330.txt
# Combined text saved as rsta_2014_0335.txt
# Processing rsta_2014_0410.pdf...
# Processing rsta_2014_0411.pdf...
# Processing rsta_2014_0451.pdf...
# Combined text saved as rsta_2014_0360.txt
# Combined text saved as rsta_2014_0220.txt
# Processing rsta_2014_0169.pdf...
# Processing rsta_2014_0379.pdf...
# Combined text saved as rsta_2014_0341.txt
# Processing rsta_2014_0424.pdf...
# Combined text saved as rsta_2014_0338.txt
# Combined text saved as rsta_2014_0339.txt
# Combined text saved as rsta_2014_0283.txt
# Processing rsta_2014_0429.pdf...
# Processing rsta_2014_0425.pdf...
# Processing rsta_2014_0426.pdf...
# Combined text saved as rsta_2014_0334.txt
# Combined text saved as rsta_2014_0449.txt
# Processing rsta_2015_0117.pdf...
# Processing rsta_2014_0457.pdf...
# Combined text saved as rsta_2014_0425.txt
# Combined text saved as rsta_2014_0363.txt
# Combined text saved as rsta_2014_0451.txt
# Processing rsta_2015_0016.pdf...
# Processing rsta_2015_0014.pdf...
# Processing rsta_2015_0108.pdf...
# Combined text saved as rsta_2014_0169.txt
# Combined text saved as rsta_2014_0410.txt
# Processing rsta_2015_0105.pdf...
# Combined text saved as rsta_2015_0117.txt
# Processing rsta_2015_0005.pdf...
# Processing rsta_2015_0343.pdf...
# Combined text saved as rsta_2014_0429.txt
# Combined text saved as rsta_2014_0426.txt
# Processing rsta_2015_0094.pdf...
# Processing rsta_2015_0104.pdf...
# Combined text saved as rsta_2015_0105.txt
# Combined text saved as rsta_2015_0343.txt
# Processing rsta_2014_0466.pdf...
# Combined text saved as rsta_2015_0016.txt
# Combined text saved as rsta_2014_0411.txt
# Combined text saved as rsta_2015_0108.txt
# Processing rsta_2015_0101.pdf...
# Processing rsta_2015_0267.pdf...
# Processing rsta_2015_0032.pdf...
# Processing rsta_2015_0056.pdf...
# Combined text saved as rsta_2014_0424.txt
# Processing rsta_2015_0019.pdf...
# Combined text saved as rsta_2014_0457.txt
# Combined text saved as rsta_2014_0466.txt
# Processing rsta_2015_0086.pdf...
# Processing rsta_2015_0083.pdf...
# Combined text saved as rsta_2014_0379.txt
# Processing rsta_2015_0191.pdf...
# Combined text saved as rsta_2015_0014.txt
# Processing rsta_2014_0445.pdf...
# Combined text saved as rsta_2015_0094.txt
# Processing rsta_2015_0152.pdf...
# Combined text saved as rsta_2015_0104.txt
# Processing rsta_2015_0060.pdf...
# Combined text saved as rsta_2015_0019.txt
# Processing rsta_2015_0069.pdf...
# Combined text saved as rsta_2015_0083.txt
# Processing rsta_2015_0449.pdf...
# Combined text saved as rsta_2015_0086.txt
# Processing rsta_2015_0448.pdf...
# Combined text saved as rsta_2015_0191.txt
# Processing rsta_2015_0053.pdf...
# Combined text saved as rsta_2015_0449.txt
# Combined text saved as rsta_2015_0032.txt
# Processing rsta_2015_0447.pdf...
# Combined text saved as rsta_2015_0448.txt
# Combined text saved as rsta_2015_0267.txt
# Processing rsta_2015_0045.pdf...
# Processing rsta_2015_0051.pdf...
# Processing rsta_2015_0050.pdf...
# Combined text saved as rsta_2015_0053.txt
# Processing rsta_2015_0207.pdf...
# Combined text saved as rsta_2015_0056.txt
# Combined text saved as rsta_2015_0447.txt
# Processing rsta_2015_0167.pdf...
# Processing rsta_2015_0170.pdf...
# Combined text saved as rsta_2015_0207.txt
# Combined text saved as rsta_2014_0445.txt
# Processing rsta_2015_0244.pdf...
# Processing rsta_2015_0173.pdf...
# Combined text saved as rsta_2015_0005.txt
# Combined text saved as rsta_2015_0060.txt
# Processing rsta_2015_0232.pdf...
# Processing rsta_2015_0164.pdf...
# Combined text saved as rsta_2015_0152.txt
# Processing rsta_2015_0328.pdf...
# Combined text saved as rsta_2015_0051.txt
# Processing rsta_2015_0332.pdf...
# Combined text saved as rsta_2015_0244.txt
# Processing rsta_2015_0340.pdf...
# Combined text saved as rsta_2015_0045.txt
# Processing rsta_2015_0330.pdf...
# Combined text saved as rsta_2015_0069.txt
# Processing rsta_2015_0334.pdf...
# Combined text saved as rsta_2015_0232.txt
# Processing rsta_2015_0272.pdf...
# Combined text saved as rsta_2015_0050.txt
# Combined text saved as rsta_2015_0167.txt
# Processing rsta_2016_0134.pdf...
# Combined text saved as rsta_2015_0170.txt
# Combined text saved as rsta_2015_0164.txt
# Processing rsta_2016_0184.pdf...
# Processing rsta_2016_0189.pdf...
# Processing rsta_2016_0192.pdf...
# Combined text saved as rsta_2015_0173.txt
# Processing rsta_2015_0264.pdf...
# Combined text saved as rsta_2015_0328.txt
# Combined text saved as rsta_2015_0340.txt
# Processing rsta_2015_0263.pdf...
# Processing rsta_2016_0093.pdf...
# Combined text saved as rsta_2015_0264.txt
# Combined text saved as rsta_2015_0332.txt
# Processing rsta_2015_0248.pdf...
# Processing rsta_2015_0320.pdf...
# Combined text saved as rsta_2015_0334.txt
# Combined text saved as rsta_2015_0330.txt
# Processing rsta_2015_0219.pdf...
# Processing rsta_2015_0318.pdf...
# Combined text saved as rsta_2015_0272.txt
# Combined text saved as rsta_2015_0101.txt
# Processing rsta_2015_0213.pdf...
# Processing rsta_2015_0220.pdf...
# Combined text saved as rsta_2016_0134.txt
# Processing rsta_2015_0429.pdf...
# Combined text saved as rsta_2015_0263.txt
# Combined text saved as rsta_2016_0093.txt
# Processing rsta_2015_0424.pdf...
# Processing rsta_2015_0420.pdf...
# Combined text saved as rsta_2016_0184.txt
# Processing rsta_2015_0371.pdf...
# Combined text saved as rsta_2015_0320.txt
# Processing rsta_2015_0373.pdf...
# Combined text saved as rsta_2015_0248.txt
# Processing rsta_2016_0229.pdf...
# Combined text saved as rsta_2016_0189.txt
# Processing rsta_2015_0368.pdf...
# Combined text saved as rsta_2015_0429.txt
# Combined text saved as rsta_2015_0420.txt
# Processing rsta_2016_0153.pdf...
# Combined text saved as rsta_2015_0424.txt
# Processing rsta_2015_0362.pdf...
# Combined text saved as rsta_2015_0219.txt
# Processing rsta_2016_0141.pdf...
# Processing rsta_2015_0293.pdf...
# Combined text saved as rsta_2015_0213.txt
# Processing rsta_2016_0051.pdf...
# Combined text saved as rsta_2015_0220.txt
# Processing rsta_2016_0045.pdf...
# Combined text saved as rsta_2015_0368.txt
# Processing rsta_2016_0049.pdf...
# Combined text saved as rsta_2015_0371.txt
# Processing rsta_2016_0050.pdf...
# Combined text saved as rsta_2016_0192.txt
# Processing rsta_2016_0127.pdf...
# Combined text saved as rsta_2016_0229.txt
# Processing rsta_2016_0033.pdf...
# Combined text saved as rsta_2016_0141.txt
# Combined text saved as rsta_2016_0153.txt
# Processing rsta_2016_0028.pdf...
# Processing rsta_2016_0031.pdf...
# Combined text saved as rsta_2016_0049.txt
# Combined text saved as rsta_2015_0373.txt
# Combined text saved as rsta_2016_0127.txt
# Processing rsta_2016_0176.pdf...
# Combined text saved as rsta_2015_0362.txt
# Processing rsta_2016_0169.pdf...
# Processing rsta_2016_0280.pdf...
# Processing rsta_2015_0352.pdf...
# Combined text saved as rsta_2015_0318.txt
# Combined text saved as rsta_2016_0051.txt
# Processing rsta_2015_0438.pdf...
# Processing rsta_2015_0434.pdf...
# Combined text saved as rsta_2016_0280.txt
# Processing rsta_2016_0212.pdf...
# Combined text saved as rsta_2016_0045.txt
# Processing rsta_2016_0211.pdf...
# Combined text saved as rsta_2016_0033.txt
# Combined text saved as rsta_2016_0028.txt
# Processing rsta_2016_0221.pdf...
# Processing rsta_2016_0222.pdf...
# Combined text saved as rsta_2016_0212.txt
# Processing rsta_2016_0081.pdf...
# Combined text saved as rsta_2016_0169.txt
# Combined text saved as rsta_2016_0031.txt
# Processing rsta_2016_0089.pdf...
# Combined text saved as rsta_2016_0176.txt
# Combined text saved as rsta_2016_0050.txt
# Processing rsta_2016_0090.pdf...
# Processing rsta_2016_0314.pdf...
# Processing rsta_2016_0316.pdf...
# Combined text saved as rsta_2015_0438.txt
# Processing rsta_2016_0096.pdf...
# Combined text saved as rsta_2015_0293.txt
# Combined text saved as rsta_2015_0352.txt
# Processing rsta_2016_0103.pdf...
# Processing rsta_2016_0097.pdf...
# Combined text saved as rsta_2015_0434.txt
# Combined text saved as rsta_2016_0096.txt
# Combined text saved as rsta_2016_0221.txt
# Processing rsta_2016_0099.pdf...
# Processing rsta_2016_0100.pdf...
# Processing rsta_2016_0205.pdf...
# Combined text saved as rsta_2016_0222.txt
# Processing rsta_2016_0227.pdf...
# Combined text saved as rsta_2016_0316.txt
# Processing rsta_2016_0163.pdf...
# Combined text saved as rsta_2016_0211.txt
# Combined text saved as rsta_2016_0089.txt
# Processing rsta_2016_0158.pdf...
# Processing rsta_2016_0209.pdf...
# Combined text saved as rsta_2016_0314.txt
# Combined text saved as rsta_2016_0081.txt
# Processing rsta_2015_0394.pdf...
# Processing rsta_2016_0373.pdf...
# Combined text saved as rsta_2016_0090.txt
# Processing rsta_2016_0375.pdf...
# Combined text saved as rsta_2016_0163.txt
# Processing rsta_2016_0367.pdf...
# Combined text saved as rsta_2016_0158.txt
# Combined text saved as rsta_2016_0099.txt
# Combined text saved as rsta_2016_0227.txt
# Processing rsta_2016_0372.pdf...
# Processing rsta_2016_0292.pdf...
# Processing rsta_2016_0286.pdf...
# Combined text saved as rsta_2016_0100.txt
# Combined text saved as rsta_2016_0205.txt
# Processing rsta_2016_0402.pdf...
# Processing rsta_2016_0262.pdf...
# Combined text saved as rsta_2016_0103.txt
# Processing rsta_2017_0031.pdf...
# Combined text saved as rsta_2015_0394.txt
# Processing rsta_2016_0406.pdf...
# Combined text saved as rsta_2016_0097.txt
# Processing rsta_2016_0411.pdf...
# Combined text saved as rsta_2016_0375.txt
# Combined text saved as rsta_2016_0373.txt
# Combined text saved as rsta_2016_0209.txt
# Processing rsta_2017_0029.pdf...
# Processing rsta_2016_0236.pdf...
# Processing rsta_2016_0235.pdf...
# Combined text saved as rsta_2016_0286.txt
# Combined text saved as rsta_2016_0367.txt
# Processing rsta_2016_0244.pdf...
# Combined text saved as rsta_2016_0402.txt
# Processing rsta_2016_0243.pdf...
# Processing rsta_2016_0298.pdf...
# Combined text saved as rsta_2016_0292.txt
# Processing rsta_2017_0239.pdf...
# Combined text saved as rsta_2017_0239.txt
# Processing rsta_2017_0008.pdf...
# Combined text saved as rsta_2017_0031.txt
# Processing rsta_2017_0014.pdf...
# Combined text saved as rsta_2016_0406.txt
# Processing rsta_2016_0327.pdf...
# Combined text saved as rsta_2016_0243.txt
# Combined text saved as rsta_2016_0235.txt
# Combined text saved as rsta_2016_0372.txt
# Processing rsta_2017_0241.pdf...
# Processing rsta_2016_0329.pdf...
# Combined text saved as rsta_2016_0262.txt
# Combined text saved as rsta_2016_0244.txt
# Processing rsta_2016_0016.pdf...
# Combined text saved as rsta_2017_0029.txt
# Processing rsta_2015_0406.pdf...
# Combined text saved as rsta_2016_0236.txt
# Processing rsta_2016_0001.pdf...
# Processing rsta_2016_0388.pdf...
# Processing rsta_2016_0385.pdf...
# Combined text saved as rsta_2016_0411.txt
# Processing rsta_2016_0387.pdf...
# Combined text saved as rsta_2016_0298.txt
# Processing rsta_2016_0396.pdf...
# Combined text saved as rsta_2017_0014.txt
# Processing rsta_2017_0180.pdf...
# Combined text saved as rsta_2017_0008.txt
# Processing rsta_2017_0112.pdf...
# Combined text saved as rsta_2017_0241.txt
# Processing rsta_2017_0262.pdf...
# Combined text saved as rsta_2015_0406.txt
# Combined text saved as rsta_2016_0388.txt
# Processing rsta_2016_0429.pdf...
# Processing rsta_2016_0431.pdf...
# Combined text saved as rsta_2016_0385.txt
# Combined text saved as rsta_2016_0327.txt
# Combined text saved as rsta_2016_0396.txt
# Processing rsta_2016_0353.pdf...
# Processing rsta_2016_0359.pdf...
# Processing rsta_2017_0058.pdf...
# Combined text saved as rsta_2016_0016.txt
# Processing rsta_2017_0068.pdf...
# Combined text saved as rsta_2017_0112.txt
# Combined text saved as rsta_2017_0262.txt
# Processing rsta_2017_0066.pdf...
# Processing rsta_2017_0310.pdf...
# Combined text saved as rsta_2016_0001.txt
# Processing rsta_2017_0220.pdf...
# Combined text saved as rsta_2016_0329.txt
# Processing rsta_2017_0101.pdf...
# Combined text saved as rsta_2017_0310.txt
# Processing rsta_2017_0100.pdf...
# Combined text saved as rsta_2016_0429.txt
# Combined text saved as rsta_2016_0359.txt
# Processing rsta_2017_0046.pdf...
# Processing rsta_2017_0043.pdf...
# Combined text saved as rsta_2017_0058.txt
# Processing rsta_2017_0205.pdf...
# Combined text saved as rsta_2017_0068.txt
# Combined text saved as rsta_2016_0353.txt
# Combined text saved as rsta_2017_0220.txt
# Processing rsta_2017_0126.pdf...
# Processing rsta_2017_0218.pdf...
# Processing rsta_2017_0151.pdf...
# Combined text saved as rsta_2016_0387.txt
# Combined text saved as rsta_2016_0431.txt
# Processing rsta_2017_0146.pdf...
# Combined text saved as rsta_2017_0066.txt
# Processing rsta_2017_0148.pdf...
# Combined text saved as rsta_2017_0101.txt
# Processing rsta_2017_0278.pdf...
# Processing rsta_2017_0143.pdf...
# Combined text saved as rsta_2017_0278.txt
# Combined text saved as rsta_2017_0046.txt
# Combined text saved as rsta_2017_0100.txt
# Processing rsta_2017_0231.pdf...
# Processing rsta_2017_0196.pdf...
# Combined text saved as rsta_2017_0180.txt
# Processing rsta_2017_0195.pdf...
# Processing rsta_2017_0224.pdf...
# Combined text saved as rsta_2017_0205.txt
# Combined text saved as rsta_2017_0146.txt
# Processing rsta_2017_0237.pdf...
# Processing rsta_2017_0232.pdf...
# Combined text saved as rsta_2017_0126.txt
# Processing rsta_2017_0105.pdf...
# Combined text saved as rsta_2017_0043.txt
# Combined text saved as rsta_2017_0151.txt
# Processing rsta_2016_0450.pdf...
# Combined text saved as rsta_2017_0224.txt
# Processing rsta_2017_0293.pdf...
# Processing rsta_2017_0294.pdf...
# Combined text saved as rsta_2017_0148.txt
# Processing rsta_2017_0303.pdf...
# Combined text saved as rsta_2017_0143.txt
# Processing rsta_2017_0300.pdf...
# Combined text saved as rsta_2017_0231.txt
# Combined text saved as rsta_2017_0232.txt
# Processing rsta_2017_0305.pdf...
# Combined text saved as rsta_2017_0294.txt
# Processing rsta_2017_0329.pdf...
# Combined text saved as rsta_2017_0303.txt
# Processing rsta_2017_0326.pdf...
# Processing rsta_2017_0176.pdf...
# Combined text saved as rsta_2017_0105.txt
# Processing rsta_2018_0112.pdf...
# Combined text saved as rsta_2017_0237.txt
# Combined text saved as rsta_2017_0196.txt
# Processing rsta_2017_0461.pdf...
# Combined text saved as rsta_2017_0218.txt
# Processing rsta_2018_0107.pdf...
# Combined text saved as rsta_2018_0112.txt
# Processing rsta_2017_0325.pdf...
# Processing rsta_2017_0376.pdf...
# Combined text saved as rsta_2017_0195.txt
# Combined text saved as rsta_2017_0293.txt
# Processing rsta_2015_0229.pdf...
# Processing rsta_2015_0342.pdf...
# Combined text saved as rsta_2017_0326.txt
# Processing rsta_2015_0151.pdf...
# Combined text saved as rsta_2016_0450.txt
# Processing rsta_2017_0258.pdf...
# Combined text saved as rsta_2017_0461.txt
# Processing rsta_2017_0242.pdf...
# Combined text saved as rsta_2017_0176.txt
# Combined text saved as rsta_2017_0305.txt
# Processing rsta_2017_0132.pdf...
# Processing rsta_2017_0133.pdf...
# Combined text saved as rsta_2017_0329.txt
# Processing rsta_2017_0137.pdf...
# Combined text saved as rsta_2015_0229.txt
# Processing rsta_2017_0364.pdf...
# Combined text saved as rsta_2015_0151.txt
# Combined text saved as rsta_2017_0258.txt
# Processing rsta_2017_0332.pdf...
# Combined text saved as rsta_2015_0342.txt
# Combined text saved as rsta_2017_0300.txt
# Processing rsta_2017_0085.pdf...
# Processing rsta_2017_0424.pdf...
# Combined text saved as rsta_2017_0325.txt
# Processing rsta_2017_0430.pdf...
# Processing rsta_2017_0426.pdf...
# Combined text saved as rsta_2017_0132.txt
# Combined text saved as rsta_2017_0137.txt
# Processing rsta_2018_0088.pdf...
# Combined text saved as rsta_2018_0107.txt
# Processing rsta_2018_0103.pdf...
# Processing rsta_2018_0168.pdf...
# Combined text saved as rsta_2017_0242.txt
# Combined text saved as rsta_2017_0133.txt
# Combined text saved as rsta_2017_0376.txt
# Processing rsta_2017_0450.pdf...
# Processing rsta_2018_0027.pdf...
# Combined text saved as rsta_2017_0332.txt
# Processing rsta_2017_0383.pdf...
# Processing rsta_2017_0399.pdf...
# Combined text saved as rsta_2017_0364.txt
# Processing rsta_2017_0394.pdf...
# Combined text saved as rsta_2018_0027.txt
# Processing rsta_2017_0396.pdf...
# Combined text saved as rsta_2017_0085.txt
# Processing rsta_2018_0139.pdf...
# Combined text saved as rsta_2017_0383.txt
# Processing rsta_2018_0137.pdf...
# Combined text saved as rsta_2017_0450.txt
# Processing rsta_2018_0135.pdf...
# Combined text saved as rsta_2017_0426.txt
# Combined text saved as rsta_2018_0168.txt
# Processing rsta_2018_0335.pdf...
# Processing rsta_2019_0117.pdf...
# Combined text saved as rsta_2017_0424.txt
# Combined text saved as rsta_2018_0139.txt
# Processing rsta_2019_0215.pdf...
# Processing rsta_2019_0153.pdf...
# Combined text saved as rsta_2018_0137.txt
# Processing rsta_2018_0225.pdf...
# Combined text saved as rsta_2018_0103.txt
# Combined text saved as rsta_2017_0394.txt
# Processing rsta_2019_0389.pdf...
# Processing rsta_2019_0222.pdf...
# Combined text saved as rsta_2018_0335.txt
# Processing rsta_2019_0152.pdf...
# Combined text saved as rsta_2018_0088.txt
# Processing rsta_2019_0219.pdf...
# Combined text saved as rsta_2017_0399.txt
# Combined text saved as rsta_2019_0153.txt
# Processing rsta_2017_0437.pdf...
# Processing rsta_2018_0127.pdf...
# Combined text saved as rsta_2017_0396.txt
# Processing rsta_2018_0240.pdf...
# Combined text saved as rsta_2019_0219.txt
# Processing rsta_2019_0138.pdf...
# Combined text saved as rsta_2019_0215.txt
# Combined text saved as rsta_2019_0152.txt
# Processing rsta_2018_0395.pdf...
# Processing rsta_2018_0409.pdf...
# Combined text saved as rsta_2018_0135.txt
# Processing rsta_2017_0470.pdf...
# Combined text saved as rsta_2019_0117.txt
# Combined text saved as rsta_2019_0138.txt
# Processing rsta_2018_0072.pdf...
# Processing rsta_2018_0206.pdf...
# Combined text saved as rsta_2017_0437.txt
# Processing rsta_2018_0208.pdf...
# Combined text saved as rsta_2018_0127.txt
# Combined text saved as rsta_2017_0430.txt
# Processing rsta_2018_0204.pdf...
# Processing rsta_2018_0205.pdf...
# Combined text saved as rsta_2018_0240.txt
# Processing rsta_2018_0218.pdf...
# Combined text saved as rsta_2018_0395.txt
# Combined text saved as rsta_2018_0225.txt
# Combined text saved as rsta_2019_0389.txt
# Processing rsta_2018_0207.pdf...
# Combined text saved as rsta_2019_0222.txt
# Processing rsta_2018_0211.pdf...
# Processing rsta_2018_0212.pdf...
# Processing rsta_2018_0217.pdf...
# Combined text saved as rsta_2017_0470.txt
# Processing rsta_2018_0203.pdf...
# Combined text saved as rsta_2018_0206.txt
# Processing rsta_2018_0216.pdf...
# Combined text saved as rsta_2018_0208.txt
# Processing rsta_2018_0210.pdf...
# Combined text saved as rsta_2018_0409.txt
# Processing rsta_2018_0215.pdf...
# Combined text saved as rsta_2018_0204.txt
# Processing rsta_2018_0214.pdf...
# Combined text saved as rsta_2018_0212.txt
# Processing rsta_2018_0209.pdf...
# Combined text saved as rsta_2018_0072.txt
# Processing rsta_2018_0213.pdf...
# Combined text saved as rsta_2018_0207.txt
# Combined text saved as rsta_2018_0210.txt
# Processing rsta_2018_0353.pdf...
# Combined text saved as rsta_2018_0216.txt
# Combined text saved as rsta_2018_0218.txt
# Processing rsta_2018_0075.pdf...
# Combined text saved as rsta_2018_0211.txt
# Processing rsta_2018_0077.pdf...
# Processing rsta_2018_0068.pdf...
# Processing rsta_2018_0069.pdf...
# Combined text saved as rsta_2018_0215.txt
# Processing rsta_2018_0076.pdf...
# Combined text saved as rsta_2018_0217.txt
# Combined text saved as rsta_2018_0203.txt
# Processing rsta_2018_0074.pdf...
# Combined text saved as rsta_2018_0205.txt
# Combined text saved as rsta_2018_0209.txt
# Processing rsta_2018_0071.pdf...
# Processing rsta_2018_0079.pdf...
# Processing rsta_2018_0070.pdf...
# Combined text saved as rsta_2018_0213.txt
# Processing rsta_2018_0067.pdf...
# Combined text saved as rsta_2018_0214.txt
# Processing rsta_2019_0090.pdf...
# Combined text saved as rsta_2018_0353.txt
# Processing rsta_2017_0471.pdf...
# Combined text saved as rsta_2018_0075.txt
# Processing rsta_2017_0480.pdf...
# Combined text saved as rsta_2018_0067.txt
# Combined text saved as rsta_2018_0069.txt
# Processing rsta_2017_0473.pdf...
# Processing rsta_2017_0464.pdf...
# Combined text saved as rsta_2019_0090.txt
# Combined text saved as rsta_2018_0068.txt
# Processing rsta_2017_0472.pdf...
# Combined text saved as rsta_2018_0071.txt
# Combined text saved as rsta_2018_0074.txt
# Processing rsta_2017_0475.pdf...
# Processing rsta_2017_0474.pdf...
# Combined text saved as rsta_2018_0079.txt
# Combined text saved as rsta_2018_0076.txt
# Processing rsta_2017_0463.pdf...
# Processing rsta_2017_0477.pdf...
# Processing rsta_2017_0478.pdf...
# Combined text saved as rsta_2017_0471.txt
# Processing rsta_2017_0468.pdf...
# Combined text saved as rsta_2018_0070.txt
# Processing rsta_2018_0386.pdf...
# Combined text saved as rsta_2017_0473.txt
# Combined text saved as rsta_2017_0480.txt
# Processing rsta_2018_0384.pdf...
# Combined text saved as rsta_2017_0477.txt
# Combined text saved as rsta_2017_0472.txt
# Processing rsta_2019_0003.pdf...
# Processing rsta_2019_0113.pdf...
# Processing rsta_2018_0255.pdf...
# Combined text saved as rsta_2018_0077.txt
# Processing rsta_2019_0089.pdf...
# Combined text saved as rsta_2017_0478.txt
# Combined text saved as rsta_2017_0475.txt
# Processing rsta_2019_0084.pdf...
# Processing rsta_2019_0071.pdf...
# Combined text saved as rsta_2017_0474.txt
# Combined text saved as rsta_2017_0468.txt
# Processing rsta_2019_0083.pdf...
# Processing rsta_2019_0082.pdf...
# Combined text saved as rsta_2019_0113.txt
# Processing rsta_2019_0081.pdf...
# Combined text saved as rsta_2019_0084.txt
# Combined text saved as rsta_2018_0255.txt
# Processing rsta_2019_0076.pdf...
# Combined text saved as rsta_2018_0386.txt
# Combined text saved as rsta_2019_0071.txt
# Processing rsta_2019_0077.pdf...
# Processing rsta_2019_0075.pdf...
# Processing rsta_2019_0073.pdf...
# Combined text saved as rsta_2017_0464.txt
# Processing rsta_2019_0078.pdf...
# Combined text saved as rsta_2019_0003.txt
# Combined text saved as rsta_2017_0463.txt
# Processing rsta_2019_0080.pdf...
# Processing rsta_2019_0145.pdf...
# Combined text saved as rsta_2019_0089.txt
# Processing rsta_2019_0006.pdf...
# Combined text saved as rsta_2019_0082.txt
# Processing rsta_2019_0086.pdf...
# Combined text saved as rsta_2019_0083.txt
# Combined text saved as rsta_2019_0076.txt
# Processing rsta_2019_0275.pdf...
# Processing rsta_2019_0095.pdf...
# Combined text saved as rsta_2019_0075.txt
# Processing rsta_2019_0094.pdf...
# Combined text saved as rsta_2019_0078.txt
# Processing rsta_2019_0045.pdf...
# Combined text saved as rsta_2019_0006.txt
# Processing rsta_2019_0015.pdf...
# Combined text saved as rsta_2019_0077.txt
# Processing rsta_2019_0048.pdf...
# ...
# Combined text saved as rsta_1900_0026.txt
# Combined text saved as rsta_1900_0025.txt
# Processing rsta_1900_0017.pdf...
# Combined text saved as rsta_1904_0017.txt
# Processing rsta_1900_0016.pdf...
# Combined text saved as rsta_1900_0023.txt
# Combined text saved as rsta_1900_0021.txt
# Processing rsta_1900_0015.pdf...
# Combined text saved as rsta_1901_0006.txt
# Processing rsta_1904_0014.pdf...
# Processing rsta_1900_0013.pdf...
# Combined text saved as rsta_1900_0018.txt
# Processing rsta_1904_0016.pdf...
# Combined text saved as rsta_1904_0019.txt
# Combined text saved as rsta_1904_0014.txt
# Processing rsta_1900_0014.pdf...
# Combined text saved as rsta_1900_0020.txt
# Processing rsta_1905_0008.pdf...
# Combined text saved as rsta_1900_0016.txt
# Processing rsta_1900_0002.pdf...
# Processing rsta_1900_0008.pdf...
# Processing rsta_1905_0007.pdf...
# Combined text saved as rsta_1900_0017.txt
# Combined text saved as rsta_1904_0016.txt
# Processing rsta_1900_0012.pdf...
# Processing rsta_1900_0010.pdf...
# Combined text saved as rsta_1900_0015.txt
# Combined text saved as rsta_1900_0013.txt
# Processing rsta_1900_0009.pdf...
# Combined text saved as rsta_1905_0008.txt
# Processing rsta_1900_0011.pdf...
# Combined text saved as rsta_1900_0012.txt
# Combined text saved as rsta_1900_0019.txt
# Combined text saved as rsta_1900_0024.txt
# Combined text saved as rsta_1900_0008.txt
# Processing rsta_1900_0006.pdf...
# Processing rsta_1900_0007.pdf...
# Processing rsta_1900_0005.pdf...
# Processing rsta_1900_0004.pdf...
# Processing rsta_1900_0003.pdf...
# Combined text saved as rsta_1900_0002.txt
# Combined text saved as rsta_1900_0009.txt
# Processing rsta_1905_0006.pdf...
# Combined text saved as rsta_1900_0010.txt
# Processing rsta_1900_0001.pdf...
# Combined text saved as rsta_1900_0011.txt
# Combined text saved as rsta_1900_0006.txt
# Processing rsta_1899_0002.pdf...
# Combined text saved as rsta_1900_0004.txt
# Processing rsta_1899_0012.pdf...
# Combined text saved as rsta_1899_0012.txt
# Combined text saved as rsta_1900_0005.txt
# Processing rsta_1899_0010.pdf...
# Processing rsta_1899_0011.pdf...
# Processing rsta_1899_0009.pdf...
# Combined text saved as rsta_1900_0003.txt
# Processing rsta_1899_0008.pdf...
# Processing rsta_1899_0007.pdf...
# Combined text saved as rsta_1905_0007.txt
# Combined text saved as rsta_1900_0007.txt
# Processing rsta_1899_0005.pdf...
# Combined text saved as rsta_1905_0006.txt
# Combined text saved as rsta_1899_0005.txt
# Processing rsta_1899_0006.pdf...
# Combined text saved as rsta_1900_0001.txt
# Combined text saved as rsta_1899_0011.txt
# Combined text saved as rsta_1899_0007.txt
# Processing rsta_1899_0001.pdf...
# Processing rsta_1899_0004.pdf...
# Processing rsta_1908_0003.pdf...
# Processing rsta_1898_0002.pdf...
# Combined text saved as rsta_1901_0003.txt
# Processing rsta_1899_0003.pdf...
# Combined text saved as rsta_1899_0008.txt
# Processing rsta_1898_0009.pdf...
# Combined text saved as rsta_1899_0002.txt
# Processing rsta_1898_0001.pdf...
# Combined text saved as rsta_1898_0002.txt
# Combined text saved as rsta_1908_0003.txt
# Processing rsta_1898_0012.pdf...
# Combined text saved as rsta_1899_0009.txt
# Combined text saved as rsta_1900_0014.txt
# Processing rsta_1898_0011.pdf...
# Processing rsta_1898_0010.pdf...
# Combined text saved as rsta_1899_0001.txt
# Processing rsta_1898_0006.pdf...
# Processing rsta_1898_0008.pdf...
# Combined text saved as rsta_1899_0010.txt
# Processing rsta_1898_0005.pdf...
# Processing rsta_1898_0007.pdf...
# Combined text saved as rsta_1898_0009.txt
# Combined text saved as rsta_1898_0012.txt
# Processing rsta_1898_0004.pdf...
# Processing rsta_1898_0003.pdf...
# Combined text saved as rsta_1898_0006.txt
# Combined text saved as rsta_1898_0010.txt
# Combined text saved as rsta_1898_0004.txt
# Processing rsta_1909_0009.pdf...
# Combined text saved as rsta_1899_0003.txt
# Processing rsta_1897_0012.pdf...
# Combined text saved as rsta_1898_0003.txt
# Combined text saved as rsta_1898_0001.txt
# Processing rsta_1909_0008.pdf...
# Processing rsta_1908_0001.pdf...
# Processing rsta_1909_0007.pdf...
# Combined text saved as rsta_1899_0006.txt
# Processing rsta_1897_0024.pdf...
# Combined text saved as rsta_1899_0004.txt
# Combined text saved as rsta_1897_0024.txt
# Combined text saved as rsta_1898_0005.txt
# Combined text saved as rsta_1898_0011.txt
# Processing rsta_1897_0023.pdf...
# Processing rsta_1897_0019.pdf...
# Combined text saved as rsta_1898_0008.txt
# Processing rsta_1897_0022.pdf...
# Combined text saved as rsta_1897_0019.txt
# Combined text saved as rsta_1897_0012.txt
# Processing rsta_1897_0018.pdf...
# Combined text saved as rsta_1909_0007.txt
# Combined text saved as rsta_1909_0009.txt
# Processing rsta_1897_0017.pdf...
# Processing rsta_1897_0015.pdf...
# Processing rsta_1897_0021.pdf...
# Processing rsta_1897_0014.pdf...
# Processing rsta_1897_0016.pdf...
# Processing rsta_1897_0020.pdf...
# Combined text saved as rsta_1897_0023.txt
# Combined text saved as rsta_1909_0008.txt
# Processing rsta_1897_0013.pdf...
# Processing rsta_1897_0001.pdf...
# Combined text saved as rsta_1898_0007.txt
# Processing rsta_1909_0006.pdf...
# Combined text saved as rsta_1897_0015.txt
# Combined text saved as rsta_1897_0013.txt
# Combined text saved as rsta_1897_0014.txt
# Processing rsta_1897_0010.pdf...
# Combined text saved as rsta_1897_0017.txt
# Processing rsta_1897_0011.pdf...
# Processing rsta_1897_0008.pdf...
# Combined text saved as rsta_1897_0010.txt
# Combined text saved as rsta_1897_0018.txt
# Combined text saved as rsta_1897_0001.txt
# Combined text saved as rsta_1897_0016.txt
# Processing rsta_1897_0007.pdf...
# Processing rsta_1897_0009.pdf...
# Processing rsta_1897_0006.pdf...
# Processing rsta_1897_0005.pdf...
# Processing rsta_1897_0003.pdf...
# Combined text saved as rsta_1897_0008.txt
# Processing rsta_1897_0004.pdf...
# Combined text saved as rsta_1909_0006.txt
# Combined text saved as rsta_1908_0001.txt
# Combined text saved as rsta_1897_0022.txt
# Processing rsta_1897_0002.pdf...
# Combined text saved as rsta_1897_0006.txt
# Processing rsta_1896_0020.pdf...
# Processing rsta_1909_0004.pdf...
# Combined text saved as rsta_1897_0007.txt
# Combined text saved as rsta_1896_0020.txt
# Processing rsta_1909_0005.pdf...
# Combined text saved as rsta_1897_0005.txt
# Processing rsta_1909_0001.pdf...
# Processing rsta_1896_0001.pdf...
# Processing rsta_1896_0003.pdf...
# Combined text saved as rsta_1897_0011.txt
# Combined text saved as rsta_1897_0004.txt
# Combined text saved as rsta_1896_0001.txt
# Combined text saved as rsta_1896_0003.txt
# Processing rsta_1896_0002.pdf...
# Combined text saved as rsta_1909_0001.txt
# Combined text saved as rsta_1897_0003.txt
# Processing rsta_1911_0006.pdf...
# Combined text saved as rsta_1909_0004.txt
# Processing rsta_1911_0004.pdf...
# Processing rsta_1911_0001.pdf...
# Combined text saved as rsta_1897_0009.txt
# Processing rsta_1911_0005.pdf...
# Processing rsta_1912_0005.pdf...
# Processing rsta_1896_0004.pdf...
# Combined text saved as rsta_1909_0005.txt
# Combined text saved as rsta_1897_0002.txt
# Processing rsta_1912_0004.pdf...
# Combined text saved as rsta_1896_0002.txt
# Processing rsta_1896_0007.pdf...
# Processing rsta_1896_0018.pdf...
# Combined text saved as rsta_1911_0004.txt
# Processing rsta_1896_0005.pdf...
# Processing rsta_1896_0017.pdf...
# Combined text saved as rsta_1897_0021.txt
# Combined text saved as rsta_1911_0001.txt
# Combined text saved as rsta_1911_0006.txt
# Combined text saved as rsta_1897_0020.txt
# Processing rsta_1896_0014.pdf...
# Processing rsta_1896_0016.pdf...
# Combined text saved as rsta_1911_0005.txt
# Processing rsta_1896_0012.pdf...
# Processing rsta_1896_0015.pdf...
# Processing rsta_1896_0013.pdf...
# Combined text saved as rsta_1896_0018.txt
# Combined text saved as rsta_1896_0014.txt
# Processing rsta_1896_0011.pdf...
# Combined text saved as rsta_1896_0012.txt
# Processing rsta_1896_0010.pdf...
# Combined text saved as rsta_1896_0017.txt
# Processing rsta_1896_0009.pdf...
# Combined text saved as rsta_1912_0005.txt
# Processing rsta_1896_0008.pdf...
# Processing rsta_1896_0006.pdf...
# Combined text saved as rsta_1896_0011.txt
# Combined text saved as rsta_1912_0004.txt
# Processing rsta_1912_0003.pdf...
# Combined text saved as rsta_1896_0016.txt
# Combined text saved as rsta_1896_0006.txt
# Combined text saved as rsta_1896_0008.txt
# Processing rsta_1912_0002.pdf...
# Processing rsta_1912_0001.pdf...
# Combined text saved as rsta_1896_0007.txt
# Processing rsta_1895_0017.pdf...
# Processing rsta_1895_0012.pdf...
# Processing rsta_1895_0018.pdf...
# Combined text saved as rsta_1896_0010.txt
# Processing rsta_1895_0016.pdf...
# Combined text saved as rsta_1896_0009.txt
# Combined text saved as rsta_1895_0017.txt
# Combined text saved as rsta_1896_0005.txt
# Processing rsta_1895_0015.pdf...
# Processing rsta_1895_0013.pdf...
# Combined text saved as rsta_1895_0016.txt
# Combined text saved as rsta_1912_0003.txt
# Processing rsta_1895_0014.pdf...
# Processing rsta_1895_0011.pdf...
# Combined text saved as rsta_1896_0004.txt
# Combined text saved as rsta_1912_0001.txt
# Combined text saved as rsta_1896_0013.txt
# Combined text saved as rsta_1895_0013.txt
# Combined text saved as rsta_1895_0012.txt
# Combined text saved as rsta_1896_0015.txt
# Processing rsta_1895_0010.pdf...
# Processing rsta_1895_0020.pdf...
# Processing rsta_1895_0019.pdf...
# Combined text saved as rsta_1895_0018.txt
# Combined text saved as rsta_1895_0015.txt
# Processing rsta_1895_0023.pdf...
# Processing rsta_1894_0002.pdf...
# Processing rsta_1894_0001.pdf...
# Processing rsta_1894_0003.pdf...
# Processing rsta_1895_0021.pdf...
# Processing rsta_1895_0022.pdf...
# Combined text saved as rsta_1912_0002.txt
# Combined text saved as rsta_1895_0014.txt
# Processing rsta_1894_0004.pdf...
# Processing rsta_1895_0009.pdf...
# Combined text saved as rsta_1894_0002.txt
# Processing rsta_1895_0007.pdf...
# Combined text saved as rsta_1895_0019.txt
# Processing rsta_1895_0008.pdf...
# Combined text saved as rsta_1894_0001.txt
# Combined text saved as rsta_1895_0008.txt
# Combined text saved as rsta_1895_0007.txt
# Combined text saved as rsta_1895_0011.txt
# Processing rsta_1894_0019.pdf...
# Processing rsta_1894_0006.pdf...
# Processing rsta_1894_0007.pdf...
# Processing rsta_1895_0006.pdf...
# Combined text saved as rsta_1894_0019.txt
# Combined text saved as rsta_1894_0003.txt
# Processing rsta_1894_0020.pdf...
# Combined text saved as rsta_1895_0023.txt
# Combined text saved as rsta_1895_0020.txt
# Processing rsta_1894_0017.pdf...
# Processing rsta_1894_0018.pdf...
# Processing rsta_1894_0021.pdf...
# Combined text saved as rsta_1894_0004.txt
# Processing rsta_1894_0016.pdf...
# Combined text saved as rsta_1895_0010.txt
# Combined text saved as rsta_1894_0007.txt
# Combined text saved as rsta_1894_0020.txt
# Combined text saved as rsta_1894_0006.txt
# Processing rsta_1894_0014.pdf...
# Processing rsta_1894_0011.pdf...
# Processing rsta_1894_0015.pdf...
# Combined text saved as rsta_1894_0017.txt
# Processing rsta_1894_0013.pdf...
# Combined text saved as rsta_1895_0022.txt
# Combined text saved as rsta_1894_0011.txt
# Combined text saved as rsta_1894_0016.txt
# Processing rsta_1894_0009.pdf...
# Combined text saved as rsta_1895_0021.txt
# Processing rsta_1894_0012.pdf...
# Processing rsta_1894_0008.pdf...
# Combined text saved as rsta_1894_0018.txt
# Combined text saved as rsta_1894_0014.txt
# Processing rsta_1893_0007.pdf...
# Processing rsta_1894_0005.pdf...
# Combined text saved as rsta_1894_0015.txt
# Combined text saved as rsta_1895_0006.txt
# Processing rsta_1893_0005.pdf...
# Processing rsta_1893_0010.pdf...
# Combined text saved as rsta_1895_0009.txt
# Combined text saved as rsta_1894_0009.txt
# Combined text saved as rsta_1894_0021.txt
# Processing rsta_1893_0011.pdf...
# Processing rsta_1893_0012.pdf...
# Processing rsta_1893_0013.pdf...
# Combined text saved as rsta_1893_0007.txt
# Combined text saved as rsta_1893_0010.txt
# Combined text saved as rsta_1893_0005.txt
# Processing rsta_1893_0009.pdf...
# Processing rsta_1893_0008.pdf...
# Combined text saved as rsta_1894_0013.txt
# Processing rsta_1893_0006.pdf...
# Combined text saved as rsta_1893_0011.txt
# Combined text saved as rsta_1893_0013.txt
# Processing rsta_1893_0003.pdf...
# Combined text saved as rsta_1893_0008.txt
# Processing rsta_1893_0016.pdf...
# Combined text saved as rsta_1893_0009.txt
# Combined text saved as rsta_1893_0012.txt
# Processing rsta_1893_0002.pdf...
# Combined text saved as rsta_1894_0008.txt
# Processing rsta_1893_0022.pdf...
# Processing rsta_1893_0021.pdf...
# Processing rsta_1893_0020.pdf...
# Processing rsta_1893_0019.pdf...
# Processing rsta_1893_0004.pdf...
# Processing rsta_1894_0010.pdf...
# Combined text saved as rsta_1894_0005.txt
# Combined text saved as rsta_1893_0016.txt
# Combined text saved as rsta_1893_0002.txt
# Processing rsta_1893_0017.pdf...
# Combined text saved as rsta_1893_0022.txt
# Processing rsta_1893_0018.pdf...
# Processing rsta_1893_0014.pdf...
# Processing rsta_1893_0015.pdf...
# Combined text saved as rsta_1893_0020.txt
# Combined text saved as rsta_1894_0012.txt
# Processing rsta_1895_0005.pdf...
# Processing rsta_1893_0001.pdf...
# Combined text saved as rsta_1893_0021.txt
# Combined text saved as rsta_1893_0019.txt
# Processing rsta_1892_0008.pdf...
# Processing rsta_1895_0004.pdf...
# Combined text saved as rsta_1895_0005.txt
# Combined text saved as rsta_1893_0003.txt
# Combined text saved as rsta_1893_0017.txt
# Processing rsta_1892_0012.pdf...
# Processing rsta_1892_0009.pdf...
# Combined text saved as rsta_1892_0008.txt
# Processing rsta_1892_0017.pdf...
# Combined text saved as rsta_1893_0001.txt
# Combined text saved as rsta_1893_0014.txt
# Processing rsta_1892_0018.pdf...
# Processing rsta_1892_0016.pdf...
# Processing rsta_1892_0015.pdf...
# Combined text saved as rsta_1895_0004.txt
# Combined text saved as rsta_1892_0012.txt
# Combined text saved as rsta_1893_0006.txt
# Combined text saved as rsta_1893_0004.txt
# Processing rsta_1892_0013.pdf...
# Processing rsta_1892_0010.pdf...
# Processing rsta_1892_0014.pdf...
# Combined text saved as rsta_1892_0009.txt
# Processing rsta_1892_0011.pdf...
# Processing rsta_1892_0007.pdf...
# Combined text saved as rsta_1893_0015.txt
# Combined text saved as rsta_1892_0016.txt
# Processing rsta_1892_0004.pdf...
# Combined text saved as rsta_1892_0017.txt
# Combined text saved as rsta_1892_0010.txt
# Processing rsta_1892_0006.pdf...
# Combined text saved as rsta_1893_0018.txt
# Processing rsta_1892_0003.pdf...
# Processing rsta_1892_0002.pdf...
# Combined text saved as rsta_1892_0004.txt
# Combined text saved as rsta_1892_0013.txt
# Processing rsta_1891_0004.pdf...
# Combined text saved as rsta_1892_0014.txt
# Combined text saved as rsta_1892_0007.txt
# Processing rsta_1891_0007.pdf...
# Processing rsta_1892_0001.pdf...
# Processing rsta_1891_0006.pdf...
# Processing rsta_1892_0005.pdf...
# Combined text saved as rsta_1892_0003.txt
# Processing rsta_1891_0010.pdf...
# Combined text saved as rsta_1892_0006.txt
# Combined text saved as rsta_1892_0002.txt
# Processing rsta_1891_0008.pdf...
# Processing rsta_1891_0009.pdf...
# Combined text saved as rsta_1892_0015.txt
# Combined text saved as rsta_1892_0011.txt
# Combined text saved as rsta_1891_0010.txt
# Processing rsta_1891_0005.pdf...
# Combined text saved as rsta_1891_0008.txt
# Combined text saved as rsta_1891_0004.txt
# Processing rsta_1891_0011.pdf...
# Processing rsta_1891_0003.pdf...
# Processing rsta_1891_0002.pdf...
# Combined text saved as rsta_1892_0018.txt
# Combined text saved as rsta_1891_0006.txt
# Combined text saved as rsta_1891_0007.txt
# Combined text saved as rsta_1891_0009.txt
# Processing rsta_1891_0001.pdf...
# Processing rsta_1895_0003.pdf...
# Processing rsta_1891_0013.pdf...
# Processing rsta_1891_0012.pdf...
# Processing rsta_1891_0014.pdf...
# Combined text saved as rsta_1891_0002.txt
# Combined text saved as rsta_1891_0003.txt
# Combined text saved as rsta_1895_0003.txt
# Processing rsta_1895_0002.pdf...
# Processing rsta_1913_0003.pdf...
# Combined text saved as rsta_1891_0001.txt
# Combined text saved as rsta_1891_0005.txt
# Combined text saved as rsta_1891_0011.txt
# Combined text saved as rsta_1891_0013.txt
# Processing rsta_1895_0001.pdf...
# Combined text saved as rsta_1892_0001.txt
# Combined text saved as rsta_1895_0002.txt
# Combined text saved as rsta_1891_0012.txt
# Combined text saved as rsta_1892_0005.txt
# Combined text saved as rsta_1891_0014.txt
# Combined text saved as rsta_1894_0010.txt
# Combined text saved as rsta_1913_0003.txt
# Combined text saved as rsta_1895_0001.txt
# Conversion complete.

# %%
#just to shut down my pc when im not home and the pc should have some rest
import os
import time

time.sleep(60)
time.sleep(60)
if os.name == 'nt':  # For Windows
    os.system('shutdown /s /t 0')

# %%
"""
Page segmentation modes: (psm)
    0    Orientation and script detection (OSD) only.
    1    Automatic page segmentation with OSD.
    2    Automatic page segmentation, but no OSD, or OCR.
    3    Fully automatic page segmentation, but no OSD. (Default)
    4    Assume a single column of text of variable sizes.
    5    Assume a single uniform block of vertically aligned text.
    6    Assume a single uniform block of text.
    7    Treat the image as a single text line.
    8    Treat the image as a single word.
    9    Treat the image as a single word in a circle.
 10    Treat the image as a single character.
 11    Sparse text. Find as much text as possible in no particular order.
 12    Sparse text with OSD.
 13    Raw line. Treat the image as a single text line,
                                                bypassing hacks that are Tesseract-specific.


OCR Engine modes: (see https://github.com/tesseract-ocr/tesseract/wiki#linux)
  0    Legacy engine only.
  1    Neural nets LSTM engine only.
  2    Legacy + LSTM engines.
  3    Default, based on what is available.
"""
